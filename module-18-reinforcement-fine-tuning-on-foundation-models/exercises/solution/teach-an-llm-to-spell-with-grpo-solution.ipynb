# %% [markdown]
# # Exercise: Teach an LLM to Spell with Group Relative Policy Optimization (GRPO)

# %% [markdown]
# Large language models (LLMs) are notoriously bad at spelling. This is partly because tokenizers break words into smaller pieces, so the model learns about sub-word units rather than whole words and their spellings.
#
# In this exercise, you'll use Group Relative Policy Optimization (GRPO) and a technique called Parameter-Efficient Fine-Tuning (PEFT) with Low-Rank Adaptation (LoRA) to teach a small LLM how to spell words. This is a classic example of teaching a model a new skill that isn't well-represented in its pre-training data.
#
# ## What you'll do in this notebook
#
# 1.  **Setup**: Import libraries and configure the environment.
# 2.  **Load the tokenizer and base model**: Use a small, instruction-tuned model as our starting point.
# 3.  **Create the dataset**: Generate a simple dataset of words and their correct spellings.
# 4.  **Evaluate the base model**: Test the model's spelling ability *before* fine-tuning to establish a baseline.
# 5.  **Configure LoRA and train**: Attach a LoRA adapter to the model and fine-tune it on the spelling dataset.
# 6.  **Evaluate the fine-tuned model**: Test the model again to see if its spelling has improved.

# %% [markdown]
# ## Setup

# %%
# Setup imports
# No changes needed in this cell

import os
import torch
from datasets import Dataset

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
)
from peft import LoraConfig, get_peft_model
from trl import SFTTrainer, SFTConfig

# Use GPU, MPS, or CPU, in that order of preference
if torch.cuda.is_available():
    device = torch.device("cuda")  # NVIDIA GPU
elif torch.backends.mps.is_available():
    device = torch.device("mps")  # Apple Silicon
else:
    device = torch.device("cpu")
torch.set_num_threads(max(1, os.cpu_count() // 2))
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Step 1. Load the tokenizer and base model
#
# The model `HuggingFaceTB/SmolLM2-135M-Instruct` is a small, instruction-tuned model that's suitable for this exercise. It has 135 million parameters, making it lightweight and efficient for fine-tuning. It's not the most powerful model, but it's a good choice for demonstrating the concepts of SFT and PEFT with LoRA, especially on a CPU or limited GPU resources.

# %%
# Student task: Load the model and tokenizer, and copy the model to the device.
# TODO: Complete the sections with **********

# See: https://huggingface.co/docs/transformers/en/models
# See: https://huggingface.co/docs/transformers/en/fast_tokenizers

# Model ID for SmolLM2-135M-Instruct
model_id = "***********"

# Load the tokenizer
tokenizer = "***********"

# Load the model
model = "***********"

# Copy the model to the device (GPU, MPS, or CPU)
model = "***********"


# <<< START SOLUTION SECTION
# Model ID for SmolLM2-135M-Instruct
model_id = "HuggingFaceTB/SmolLM2-135M-Instruct"

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load the model
model = AutoModelForCausalLM.from_pretrained(
    model_id,
)

# Copy the model to the device (GPU, MPS, or CPU)
model = model.to(device)
# <<< END SOLUTION SECTION

print("Model parameters (total):", sum(p.numel() for p in model.parameters()))
# Out:
# Model parameters (total): 134515008

# %% [markdown]
# ## Step 2. Create the dataset

# %%
# Create a list of words of different lengths
# No changes are needed in this cell.

# fmt: off
ALL_WORDS = [
    "idea", "glow", "rust", "maze", "echo", "wisp", "veto", "lush", "gaze", "knit", "fume", "plow",
    "void", "oath", "grim", "crisp", "lunar", "fable", "quest", "verge", "brawn", "elude", "aisle",
    "ember", "crave", "ivory", "mirth", "knack", "wryly", "onset", "mosaic", "velvet", "sphinx",
    "radius", "summit", "banner", "cipher", "glisten", "mantle", "scarab", "expose", "fathom",
    "tavern", "fusion", "relish", "lantern", "enchant", "torrent", "capture", "orchard", "eclipse",
    "frescos", "triumph", "absolve", "gossipy", "prelude", "whistle", "resolve", "zealous",
    "mirage", "aperture", "sapphire",
]
# fmt: on

# %%
# Student Task: Create a Hugging Face Dataset with the prompt that asks the model to spell the word
# with hyphens between the letters.
# TODO: Complete the sections with **********


def generate_records():
    for word in ALL_WORDS:
        yield {
            # We will use the GRPOTrainer which expects to receieve formatted prompts
            # to pass to the LLM
            # https://huggingface.co/docs/trl/main/en/grpo_trainer
            # "**********": f"**********",
            # <<< START SOLUTION SECTION
            "prompt": (
                f"You spell words with hyphens between the letters like this W-O-R-D.\nWord:\n{word}\n\n"
                + "Spelling:\n"
            ),
            # >>> END SOLUTION SECTION
            # Before using GRPOTrainer, will run a few epochs of supervised-fine tuning (SFT)
            # which can be useful to give an initial nudge to the model. Thus we need to provide
            # the gold standard answer.
            # See the documentation for more details:
            # https://huggingface.co/docs/trl/en/sft_trainer#expected-dataset-type-and-format
            # "**********": "-".join(word).upper() + ".",
            # <<< START SOLUTION SECTION
            "completion": "-".join(word).upper() + ".",
            # >>> END SOLUTION SECTION
            # GRPOTrainer does not expect a completion, but we can add extra columns to our dataset
            # that our reward functions will use to grade the completions provided by the LLM.
            "word": word,
            "spelling": "-".join(word).upper(),
        }


ds = Dataset.from_generator(generate_records)

ds = ds.train_test_split(test_size=0.1, seed=42)

# Show the first item of the train split
ds["train"][0]
# Out:
# {'prompt': 'You spell words with hyphens between the letters like this W-O-R-D.\nWord:\ntriumph\n\nSpelling:\n',
#  'completion': 'T-R-I-U-M-P-H.',
#  'word': 'triumph',
#  'spelling': 'T-R-I-U-M-P-H'}

# %% [markdown]
# ## Step 3. Evaluate the base model
#
# Before we fine-tune the model, let's see how it performs on the spelling task. We'll create a helper function to generate a spelling for a given word and compare it to the correct answer.

# %%
# Create a helper function that will help us visualize the performance of the model
# No changes needed in this cell


def check_spelling(
    model, tokenizer, prompt: str, actual_spelling: str, max_new_tokens: int = 20
) -> (str, str):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    gen = model.generate(
        **inputs, max_new_tokens=max_new_tokens, use_cache=False
    )  # No parameters = greedy search
    output = tokenizer.decode(gen[0], skip_special_tokens=True)

    # Extract the generated spelling from the full output string
    proposed_spelling = output.split("Spelling:\n")[-1].strip().split("\n")[0].strip()

    # strip any whitepsace from the actual spelling
    actual_spelling = actual_spelling.strip()

    print(
        f"Proposed: {proposed_spelling} | Actual: {actual_spelling} "
        f"| Matches: {'✅' if proposed_spelling == actual_spelling else '❌'}"
    )

    # Remove hyphens for a character-by-character comparison
    proposed_spelling = proposed_spelling.replace("-", "")
    actual_spelling = actual_spelling.replace("-", "")

    # Calculate the proportion of the spelling that was correct
    num_correct = sum(1 for a, b in zip(actual_spelling, proposed_spelling) if a == b)

    return num_correct / len(actual_spelling)  # Return proportion correct

# %%
# Student task: Evaluate the base model's spelling ability
# We expect it to perform poorly, as it hasn't been trained for this task.

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    spelling = example["spelling"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=spelling,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Proposed: trium | Actual: T-R-I-U-M-P-H | Matches: ❌
# Proposed: sapp | Actual: S-A-P-P-H-I-R-E | Matches: ❌
# Proposed: expose | Actual: E-X-P-O-S-E | Matches: ❌
# Proposed: fres | Actual: F-R-E-S-C-O-S | Matches: ❌
# Proposed: wisp | Actual: W-I-S-P | Matches: ❌
# Proposed: mi-er-ge | Actual: M-I-R-A-G-E | Matches: ❌
# Proposed: ivory | Actual: I-V-O-R-Y | Matches: ❌
# Proposed: onset | Actual: O-N-S-E-T | Matches: ❌
# Proposed: elude | Actual: E-L-U-D-E | Matches: ❌
# Proposed: sphinx | Actual: S-P-H-I-N-X | Matches: ❌
# Proposed: brawn | Actual: B-R-A-W-N | Matches: ❌
# Proposed: goss | Actual: G-O-S-S-I-P-Y | Matches: ❌
# Proposed: enchant | Actual: E-N-C-H-A-N-T | Matches: ❌
# Proposed: tavern | Actual: T-A-V-E-R-N | Matches: ❌
# Proposed: whistle | Actual: W-H-I-S-T-L-E | Matches: ❌
# Proposed: W-O-R-D | Actual: C-A-P-T-U-R-E | Matches: ❌
# Proposed: echo | Actual: E-C-H-O | Matches: ❌
# Proposed: mirth | Actual: M-I-R-T-H | Matches: ❌
# Proposed: cris | Actual: C-R-I-S-P | Matches: ❌
# Proposed: zeal | Actual: Z-E-A-L-O-U-S | Matches: ❌
# 0.0/20.0 words correct

# %% [markdown]
# As expected, the base model is terrible at spelling. It mostly just repeats the word back. Now, let's fine-tune it.

# %% [markdown]
# ## Step 4. Configure LoRA and train the model

# %% [markdown]
# Let’s attach a LoRA adapter to the base model. We use a LoRA config so only a tiny fraction of parameters are trainable. Read more here: [LoRA](https://huggingface.co/docs/peft/main/en/conceptual_guides/lora).

# %%
# Student task: Configure LoRA for a causal LM and wrap the model with get_peft_model
# Complete the sections with **********

# Print how many params are trainable at first
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(
    f"Trainable params BEFORE: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)"
)

# See: https://huggingface.co/docs/peft/package_reference/lora
# lora_config = LoraConfig(
#     r=**********,                 # Rank of the update matrices. Lower value = fewer trainable parameters.
#     lora_alpha=**********,        # LoRA scaling factor.
#     lora_dropout=**********,      # Dropout probability for LoRA layers.
#     bias="none",
#     task_type=**********,         # Causal Language Modeling.
# )
# # Wrap the base model with get_peft_model
# model = get_peft_model(**********, **********)

# <<< START SOLUTION SECTION
lora_config = LoraConfig(
    r=64,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)
model = get_peft_model(model, lora_config)
# >>> END SOLUTION SECTION

# Print the number of trainable parameters after applying LoRA
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(
    f"Trainable params AFTER: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)"
)
# Out:
# Trainable params BEFORE: 134,515,008 / 134,515,008 (100.00%)
# Trainable params AFTER: 3,686,400 / 138,201,408 (2.67%)

# %% [markdown]
# Now let’s set the training arguments. We'll use `SFTConfig` from the TRL library, which is a wrapper around the standard `TrainingArguments`. We keep epochs, batch size, and sequence length modest to finish training quickly.

# %%
# Train the model for a few epochs using SFT before GRPO as in certain cases
# they can work together synergystically.
# See: https://arxiv.org/html/2507.08267v1
# No changes needed here

output_dir = "data/model"

training_args = SFTConfig(
    output_dir=output_dir,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=2,
    num_train_epochs=10,
    learning_rate=5 * 1e-4,
    logging_steps=20,
    eval_strategy="steps",
    eval_steps=20,
    save_strategy="no",
    report_to=[],
    fp16=False,
    lr_scheduler_type="cosine",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=ds["train"],
    eval_dataset=ds["test"],
    args=training_args,
)
trainer.train()

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    spelling = example["spelling"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=spelling,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
#     <div>
#
#       <progress value='70' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [70/70 00:34, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Entropy</th>
#       <th>Num Tokens</th>
#       <th>Mean Token Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>1.072800</td>
#       <td>0.859614</td>
#       <td>2.348770</td>
#       <td>6833.000000</td>
#       <td>0.693884</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.527100</td>
#       <td>0.743408</td>
#       <td>2.084722</td>
#       <td>13603.000000</td>
#       <td>0.730847</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.428100</td>
#       <td>0.732658</td>
#       <td>2.029728</td>
#       <td>20407.000000</td>
#       <td>0.741263</td>
#     </tr>
#   </tbody>
# </table><p>
# /voc/data/venv2/lib/python3.12/site-packages/torch/utils/checkpoint.py:86: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# Proposed: T-I-R-U-M-P-H. | Actual: T-R-I-U-M-P-H | Matches: ❌
# Proposed: S-A-P-I-C-R-H. | Actual: S-A-P-P-H-I-R-E | Matches: ❌
# Proposed: E-X-P-S-E-T. | Actual: E-X-P-O-S-E | Matches: ❌
# Proposed: F-S-R-E-C-O-S. | Actual: F-R-E-S-C-O-S | Matches: ❌
# Proposed: W-I-P-S. | Actual: W-I-S-P | Matches: ❌
# Proposed: M-I-R-E-G. | Actual: M-I-R-A-G-E | Matches: ❌
# Proposed: I-V-O-R-Y. | Actual: I-V-O-R-Y | Matches: ❌
# Proposed: O-N-S-H-O-R-D. | Actual: O-N-S-E-T | Matches: ❌
# Proposed: E-L-E-U-D. | Actual: E-L-U-D-E | Matches: ❌
# Proposed: S-P-H-I-N-X. | Actual: S-P-H-I-N-X | Matches: ❌
# Proposed: B-R-A-N-Y. | Actual: B-R-A-W-N | Matches: ❌
# Proposed: G-S-O-P-I-Y. | Actual: G-O-S-S-I-P-Y | Matches: ❌
# Proposed: E-N-C-H-A-N-T. | Actual: E-N-C-H-A-N-T | Matches: ❌
# Proposed: T-A-A-N-R. | Actual: T-A-V-E-R-N | Matches: ❌
# Proposed: W-H-I-S-E. | Actual: W-H-I-S-T-L-E | Matches: ❌
# Proposed: C-U-P-H-E-R-T. | Actual: C-A-P-T-U-R-E | Matches: ❌
# Proposed: E-C-H-O-R-E. | Actual: E-C-H-O | Matches: ❌
# Proposed: M-I-R-T. | Actual: M-I-R-T-H | Matches: ❌
# Proposed: C-R-I-S-P. | Actual: C-R-I-S-P | Matches: ❌
# Proposed: Z-E-A-L-O-U-S. | Actual: Z-E-A-L-O-U-S | Matches: ❌
# 13.51309523809524/20.0 words correct

# %% [markdown]
# The number of words has slightly increased. Let's try training using GRPO now.
#
# First let's create some reward functions.

# %%
# Student Task: Create a helper function proportion_correct that takes a word and
# a proposed spelling from the LLM and returns a score where every matched character
# adds +1 and every  mismatched character subtracts 1 from the reward--including the
# hyphens.
# TODO: Replace occurences of **********

import re


def proportion_correct(word, proposed_spelling):
    correct_spelling = "-".join(word).upper()

    score = 0.0

    # Pad to the same length to handle extra characters
    max_len = max(len(correct_spelling), len(proposed_spelling))
    proposed_spelling_padded = proposed_spelling.ljust(max_len, " ")
    correct_spelling_padded = correct_spelling.ljust(max_len, " ")

    for a, b in zip(correct_spelling_padded, proposed_spelling_padded):
        # Add 1 for matched characters, and subtract one for mismatched
        # **********

        # <<< START SOLUTION SECTION
        if a == b:
            score += 1
        else:
            score -= 1
        # >>> END SOLUTION SECTION

    return score / (
        len(correct_spelling)
    )  # Normalize by length of spelling, including dashes


assert proportion_correct("hello", "H-E-L-L-O") == 9 / 9
assert proportion_correct("hello", "H-E-L-") == 3 / 9
assert proportion_correct("hello", "H-E-L-L-O!") == 8 / 9

# %%
# Create a `reward_spelling` function that receives a batch of completions and the associated word values
# No changes needed here

import numpy as np


def reward_spelling(completions, word, **kwargs):
    """Reward function that rewards completions with more unique letters."""

    completion_strings = [
        completion.split("\n")[0].strip() for completion in completions
    ]
    words = [w for w in word]

    rewards = [proportion_correct(w, c) for w, c in zip(words, completion_strings)]

    # When training, GRPO will pass multiple completions and words to this function.
    # We print just the first one to observe what is happening under the hood.
    print("=====")
    print(
        "Completion example first line:",
        words[0],
        "->",
        completion_strings[0].strip().split("\n")[0].strip(),
    )
    print(f"Spelling mean and std: {np.mean(rewards):.3f} +/- {np.std(rewards):.3f}")
    return rewards


assert reward_spelling(
    completions=[
        "H-E-L-L-O",
        "H-E-L-",
        "H-E-L-L-O!",
    ],
    word=[
        "hello",
        "hello",
        "hello",
    ],
) == [1, 3 / 9, 8 / 9]
# Out:
# =====
# Completion example first line: hello -> H-E-L-L-O
# Spelling mean and std: 0.741 +/- 0.292

# %%
# Student task: Create a reward of 1.0 for completions starting with a string
# formatted like X-Y-Z else return 0.0
# TODO: Replace sections marked with **********


def reward_response_in_form_of_letter_dash_letter(completions, word, **kwargs):
    """Reward function that gives a bonus for completions in the form of LETTER-DASH-LETTER."""
    pattern = re.compile(r"^([A-Z]-)+[A-Z]")  # Pattern for LETTER-DASH-LETTER

    words = [w for w in word]

    # Normalize the completions, taking the first line and removing extra whitespace
    completion_strings = [
        completion.split("\n")[0].strip() for completion in completions
    ]

    # Create a list of rewards corresponding to completions
    # Each completion that matches the pattern should receive 1.0,
    # else 0.0
    # rewards = [
    #     **********
    # ]

    # <<< START COMPLETION SECTION
    rewards = [
        1.0 if pattern.match(c) else 0.0 for w, c in zip(words, completion_strings)
    ]
    # >>> END COMPLETION SECTION

    print(
        f"Letter-dash-letter rewards mean and std: {np.mean(rewards):.3f} +/- {np.std(rewards):.3f}"
    )
    return rewards


assert reward_response_in_form_of_letter_dash_letter(
    completions=[
        "H-E-L-L-O",
        "hello",
        "Hi!",
    ],
    word=[
        "hello",
        "hello",
        "hello",
    ],
) == [1, 0, 0]
# Out:
# Letter-dash-letter rewards mean and std: 0.333 +/- 0.471

# %%
# Student task: Set the GRPOConfig and initialize the trainer
# See: https://huggingface.co/docs/trl/main/en/grpo_trainer
# TODO: Complete the sections with **********

from trl import GRPOConfig, GRPOTrainer

training_args = GRPOConfig(
    output_dir="data/spelling-grpo",
    max_completion_length=30,
    logging_steps=5,
    # learning_rate=**********,
    # num_train_epochs=**********,
    # per_device_train_batch_size=**********,
    # num_generations=**********,
    # lr_scheduler_type=**********,
    # beta=**********,
    # <<< START SOLUTION SECTION
    learning_rate=5e-5,
    num_train_epochs=10,  # We'll train just for a few epochs
    per_device_train_batch_size=8,  # The batch size for training
    num_generations=4,  # Determines the number of completions to compute for each single prompt
    lr_scheduler_type="cosine",
    beta=0.0,
    # >>> END SOLUTION SECTION
)
trainer = GRPOTrainer(
    model=model,
    # Add the parameter for the reward functions
    # **********
    # <<< START SOLUTION SECTION
    reward_funcs=[
        reward_spelling,
        reward_response_in_form_of_letter_dash_letter,
    ],
    # >>> END SOLUTION SECTION
    args=training_args,
    train_dataset=ds["train"],
)
trainer.train()
# Out:
# INFO 03-31 04:36:27 [__init__.py:241] Automatically detected platform cuda.
# =====
# Completion example first line: mirth -> M-I-H-R-T.
# Spelling mean and std: -0.314 +/- 1.988
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
#     <div>
#
#       <progress value='270' max='270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [270/270 04:19, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.032200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.026300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.064900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.006100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.033400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>-0.015500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.015500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>-0.003800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.062800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>-0.028700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.026900</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.045600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>-0.012000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.011700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>-0.014300</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>-0.025900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>-0.003900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.024400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>-0.010900</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.033000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>-0.023600</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>-0.008100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>-0.027700</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>-0.033100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.035200</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.015200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.012300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>-0.005800</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.064900</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.014000</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>-0.008000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.018300</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.038300</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>-0.028100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>-0.009900</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.041700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.010900</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.035700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>-0.016800</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>-0.021600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>-0.009600</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>-0.009600</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>-0.015100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.018000</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>-0.005000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>-0.046000</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>-0.005600</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>-0.045900</td>
#     </tr>
#   </tbody>
# </table><p>
# =====
# Completion example first line: mantle -> M-A-T-L-R.
# Spelling mean and std: 0.216 +/- 0.358
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: summit -> S-U-M-T-I-N.
# Spelling mean and std: 0.148 +/- 0.393
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-C-E-R.
# Spelling mean and std: 0.181 +/- 0.312
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-Y-L-Y.
# Spelling mean and std: 0.237 +/- 0.556
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-S-L.
# Spelling mean and std: -0.089 +/- 0.623
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-W-B-N.
# Spelling mean and std: 0.036 +/- 0.081
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-Y-N.
# Spelling mean and std: 0.111 +/- 0.136
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: sapphire -> S-A-P-P-I-A-R-H.
# Spelling mean and std: 0.114 +/- 0.470
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: fathom -> F-A-C-H-E.
# Spelling mean and std: -0.097 +/- 0.269
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-W-O-R-D.
# Spelling mean and std: -0.163 +/- 0.177
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-H-T.
# Spelling mean and std: 0.117 +/- 0.411
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-S-I-P.
# Spelling mean and std: 0.208 +/- 0.353
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-E-L-U-D.
# Spelling mean and std: 0.180 +/- 0.262
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-I-S-O-T-A.
# Spelling mean and std: 0.107 +/- 0.354
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: glow -> G-O-L-V-E-N.
# Spelling mean and std: -0.150 +/- 0.289
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> K-I-N-Y-T.
# Spelling mean and std: 0.236 +/- 0.414
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-R-e-U-G.
# Spelling mean and std: 0.126 +/- 0.407
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-R-E-G.
# Spelling mean and std: 0.386 +/- 0.301
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-E-U-T.
# Spelling mean and std: 0.151 +/- 0.150
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-H-C-H-O-R.
# Spelling mean and std: 0.393 +/- 0.472
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-E-C-O-S.
# Spelling mean and std: 0.144 +/- 0.362
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-U-N.
# Spelling mean and std: 0.333 +/- 0.242
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-E-S.
# Spelling mean and std: 0.273 +/- 0.233
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-I-R-A-M.
# Spelling mean and std: 0.045 +/- 0.348
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-P-E-F-I-A.
# Spelling mean and std: 0.235 +/- 0.395
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-D-E.
# Spelling mean and std: -0.021 +/- 0.543
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: fusion -> F-U-S-O-R-A-T.
# Spelling mean and std: 0.034 +/- 0.163
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-P.
# Spelling mean and std: 0.573 +/- 0.286
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-Y-N-E-L.
# Spelling mean and std: 0.250 +/- 0.127
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-R-L-E-D.
# Spelling mean and std: 0.303 +/- 0.195
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-H.
# Spelling mean and std: 0.062 +/- 0.381
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-A-R-Y.
# Spelling mean and std: 0.073 +/- 0.398
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-P-A-S-P-E-R-I-N-E.
# Spelling mean and std: 0.193 +/- 0.229
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-Y-R-U-E.
# Spelling mean and std: 0.538 +/- 0.332
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-U-T.
# Spelling mean and std: 0.544 +/- 0.311
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-A-N-R-O-M.
# Spelling mean and std: 0.258 +/- 0.270
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-U-R-T.
# Spelling mean and std: 0.540 +/- 0.226
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-R-E-L.
# Spelling mean and std: 0.059 +/- 0.263
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-R-E-G.
# Spelling mean and std: 0.131 +/- 0.338
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-C-O-S-I-N.
# Spelling mean and std: 0.067 +/- 0.170
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-R.
# Spelling mean and std: 0.264 +/- 0.235
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-M-A-T.
# Spelling mean and std: 0.287 +/- 0.409
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-A-B.
# Spelling mean and std: 0.268 +/- 0.154
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-O-T-U-S.
# Spelling mean and std: 0.011 +/- 0.470
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-E-U-D.
# Spelling mean and std: 0.264 +/- 0.333
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: idea -> I-D-I-G-O-R-K.
# Spelling mean and std: -0.261 +/- 0.717
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-I-S-E-L.
# Spelling mean and std: 0.198 +/- 0.353
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> [T-I-R-U-M-P].
# Spelling mean and std: 0.077 +/- 0.603
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: radius -> R-U-S-A-R-D.
# Spelling mean and std: -0.042 +/- 0.142
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-S-C-I-L-A-N.
# Spelling mean and std: 0.038 +/- 0.122
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E.
# Spelling mean and std: 0.409 +/- 0.450
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-e-o-h.
# Spelling mean and std: 0.088 +/- 0.178
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-L.
# Spelling mean and std: 0.190 +/- 0.475
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: brawn -> B-R-A-N-E.
# Spelling mean and std: 0.221 +/- 0.144
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-e.
# Spelling mean and std: 0.227 +/- 0.309
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-L-O-S-A-R.
# Spelling mean and std: -0.210 +/- 1.146
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-A-L-I-C.
# Spelling mean and std: 0.481 +/- 0.344
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-T-R-N.
# Spelling mean and std: 0.096 +/- 0.223
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-I-P-S.
# Spelling mean and std: 0.120 +/- 0.187
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.370 +/- 0.227
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-I-T-L-E.
# Spelling mean and std: 0.146 +/- 0.389
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.390 +/- 0.319
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-O-S-H-O-P.
# Spelling mean and std: -0.016 +/- 0.994
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-L-E.
# Spelling mean and std: 0.080 +/- 0.149
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-T-I-R-F.
# Spelling mean and std: 0.084 +/- 0.229
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-I-S-E.
# Spelling mean and std: 0.237 +/- 0.336
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-V-H-P.
# Spelling mean and std: 0.298 +/- 0.186
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-S-I-R.
# Spelling mean and std: 0.455 +/- 0.199
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> Ben-A-N-R-O-N.
# Spelling mean and std: -0.002 +/- 0.200
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: ember -> E-B-U-R-E.
# Spelling mean and std: 0.125 +/- 0.188
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-A-S-I-C.
# Spelling mean and std: 0.250 +/- 0.222
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-L-R-U-L-E.
# Spelling mean and std: 0.358 +/- 0.096
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-S.
# Spelling mean and std: 0.004 +/- 0.649
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: oath -> O-A-H-T.
# Spelling mean and std: 0.323 +/- 0.409
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-C-I-R-D.
# Spelling mean and std: 0.115 +/- 0.385
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.685 +/- 0.267
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-S.
# Spelling mean and std: 0.057 +/- 0.270
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.403 +/- 0.397
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-R-A-E.
# Spelling mean and std: 0.549 +/- 0.305
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-U-H-L-M-E.
# Spelling mean and std: 0.088 +/- 0.127
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-E-O-T-E.
# Spelling mean and std: 0.401 +/- 0.396
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-R-I-S-T.
# Spelling mean and std: 0.346 +/- 0.424
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-V-E-T.
# Spelling mean and std: 0.712 +/- 0.243
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: glow -> G-L-O-V.
# Spelling mean and std: 0.364 +/- 0.269
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-T-E.
# Spelling mean and std: 0.115 +/- 0.264
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-C-O-R-D.
# Spelling mean and std: 0.253 +/- 0.188
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-I-S-E-L.
# Spelling mean and std: 0.318 +/- 0.292
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-l-O-S.
# Spelling mean and std: 0.250 +/- 0.396
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-U-R-D.
# Spelling mean and std: 0.250 +/- 0.369
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.616 +/- 0.247
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-S-R-O-B.
# Spelling mean and std: 0.261 +/- 0.200
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lunar -> L-A-R-U-N.
# Spelling mean and std: 0.264 +/- 0.266
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-A-S-I-R.
# Spelling mean and std: 0.223 +/- 0.269
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-C-L-E-S-I-N.
# Spelling mean and std: 0.087 +/- 0.139
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-O-H-M-A.
# Spelling mean and std: -0.010 +/- 0.180
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-H-R-R-E.
# Spelling mean and std: 0.161 +/- 0.315
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-R-N.
# Spelling mean and std: 0.148 +/- 0.136
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-I-P-S.
# Spelling mean and std: 0.323 +/- 0.183
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.339 +/- 0.416
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E.
# Spelling mean and std: 0.179 +/- 0.864
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-L-R-U.
# Spelling mean and std: 0.138 +/- 0.310
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-V-E-L.
# Spelling mean and std: 0.314 +/- 0.199
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-I-K-T.
# Spelling mean and std: 0.187 +/- 0.278
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-H-R-O.
# Spelling mean and std: 0.313 +/- 0.260
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-M-U-T-I-M.
# Spelling mean and std: 0.216 +/- 0.329
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: frescos -> F-R-S-E-C-S.
# Spelling mean and std: 0.125 +/- 0.158
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-O-R-E.
# Spelling mean and std: 0.183 +/- 0.646
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-S-O-P-I-Y.
# Spelling mean and std: 0.129 +/- 0.246
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-S.
# Spelling mean and std: 0.067 +/- 0.573
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: idea -> D-I-E-A.
# Spelling mean and std: 0.179 +/- 0.638
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-S.
# Spelling mean and std: 0.352 +/- 0.263
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.544 +/- 0.322
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-C-O-S-S.
# Spelling mean and std: 0.243 +/- 0.333
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-S-R-A-I-L.
# Spelling mean and std: 0.331 +/- 0.166
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-V-T.
# Spelling mean and std: 0.322 +/- 0.294
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: glow -> G-L-O-W.
# Spelling mean and std: 0.750 +/- 0.199
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-T.
# Spelling mean and std: 0.003 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.444 +/- 0.283
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-H-A-M-E.
# Spelling mean and std: 0.072 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-I-R-E.
# Spelling mean and std: -0.163 +/- 0.316
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-A-N-N-B-L.
# Spelling mean and std: 0.446 +/- 0.152
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-I-R-U-M-P-H-A-R.
# Spelling mean and std: 0.267 +/- 0.091
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-E-B.
# Spelling mean and std: 0.404 +/- 0.298
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-I-T.
# Spelling mean and std: 0.157 +/- 0.339
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-R-N.
# Spelling mean and std: 0.403 +/- 0.357
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-H-T.
# Spelling mean and std: 0.264 +/- 0.310
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-I-N-H-X.
# Spelling mean and std: 0.294 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-A-T-O.
# Spelling mean and std: -0.012 +/- 0.194
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-O-R-E.
# Spelling mean and std: 0.271 +/- 0.339
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-N-W-I.
# Spelling mean and std: 0.264 +/- 0.168
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-A-U-D.
# Spelling mean and std: 0.528 +/- 0.293
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-R-D.
# Spelling mean and std: 0.178 +/- 0.216
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: enchant -> E-N-C-A-N-T.
# Spelling mean and std: 0.231 +/- 0.300
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-A-T-S-I-L.
# Spelling mean and std: 0.026 +/- 0.165
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-R-H.
# Spelling mean and std: 0.394 +/- 0.362
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I-N.
# Spelling mean and std: 0.386 +/- 0.207
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-T-A-N.
# Spelling mean and std: 0.205 +/- 0.128
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-U-L-E-V.
# Spelling mean and std: 0.317 +/- 0.269
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-U-R-Y.
# Spelling mean and std: 0.194 +/- 0.401
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.509 +/- 0.047
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-I-T-L.
# Spelling mean and std: 0.272 +/- 0.354
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-R-A-P-E-R-T-U-R-E.
# Spelling mean and std: 0.370 +/- 0.389
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-V-X-T.
# Spelling mean and std: 0.466 +/- 0.365
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-E-M.
# Spelling mean and std: 0.201 +/- 0.337
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-E-U-D-A.
# Spelling mean and std: 0.234 +/- 0.314
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-R-E.
# Spelling mean and std: 0.485 +/- 0.273
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-I-S-R-P.
# Spelling mean and std: 0.497 +/- 0.310
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-R-I-L-U-N.
# Spelling mean and std: 0.444 +/- 0.358
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-U-R-A-T.
# Spelling mean and std: 0.462 +/- 0.298
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-S-H-R.
# Spelling mean and std: 0.265 +/- 0.215
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-A-B-N.
# Spelling mean and std: 0.316 +/- 0.259
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-K-A-B.
# Spelling mean and std: 0.433 +/- 0.234
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-M-S.
# Spelling mean and std: 0.200 +/- 0.198
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-H-T.
# Spelling mean and std: 0.299 +/- 0.128
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-L.
# Spelling mean and std: 0.036 +/- 0.373
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-T.
# Spelling mean and std: 0.135 +/- 0.216
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-P-A-R-I-T.
# Spelling mean and std: -0.202 +/- 0.663
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-C-E-D.
# Spelling mean and std: 0.192 +/- 0.139
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-I-S-E-L.
# Spelling mean and std: 0.270 +/- 0.591
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-E-R-G-E.
# Spelling mean and std: 0.651 +/- 0.282
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E-R.
# Spelling mean and std: 0.448 +/- 0.374
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-O-S-H-O-P-I-Y.
# Spelling mean and std: 0.492 +/- 0.260
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-A-L-T-E.
# Spelling mean and std: 0.307 +/- 0.276
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-I-M.
# Spelling mean and std: 0.299 +/- 0.290
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-P-H-R-E.
# Spelling mean and std: 0.087 +/- 0.124
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-R-I-S-L.
# Spelling mean and std: 0.143 +/- 0.495
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-A-N-N-E-R.
# Spelling mean and std: 0.477 +/- 0.287
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-A-D.
# Spelling mean and std: 0.491 +/- 0.219
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-A-N.
# Spelling mean and std: 0.327 +/- 0.284
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-R-T.
# Spelling mean and std: 0.222 +/- 0.116
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-M-U-P-H.
# Spelling mean and std: 0.471 +/- 0.091
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.349 +/- 0.367
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: expose -> E-X-P-S-H-E-R.
# Spelling mean and std: 0.281 +/- 0.221
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-P-T-E-R.
# Spelling mean and std: 0.253 +/- 0.173
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-E-R-U-V.
# Spelling mean and std: 0.148 +/- 0.138
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-E-D.
# Spelling mean and std: 0.457 +/- 0.318
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-R-I-L.
# Spelling mean and std: 0.153 +/- 0.375
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-I-S-H.
# Spelling mean and std: 0.477 +/- 0.294
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-A-B.
# Spelling mean and std: 0.280 +/- 0.219
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-V-E.
# Spelling mean and std: 0.058 +/- 0.223
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-A-R-N-E.
# Spelling mean and std: 0.542 +/- 0.301
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-R-E.
# Spelling mean and std: 0.205 +/- 0.128
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-W-O-R-D.
# Spelling mean and std: 0.395 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: idea -> D-I-A-S-E.
# Spelling mean and std: 0.393 +/- 0.552
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-I-N-T.
# Spelling mean and std: 0.080 +/- 0.302
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-S-E-Z.
# Spelling mean and std: 0.224 +/- 0.228
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: verge -> R-U-V-E-G.
# Spelling mean and std: 0.260 +/- 0.235
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-I-N.
# Spelling mean and std: 0.546 +/- 0.273
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-O-T.
# Spelling mean and std: 0.057 +/- 0.372
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-U-C-H.
# Spelling mean and std: 0.177 +/- 0.180
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-R-E.
# Spelling mean and std: 0.413 +/- 0.170
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-A-M-T.
# Spelling mean and std: -0.073 +/- 0.256
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-I-F-E-R.
# Spelling mean and std: 0.181 +/- 0.201
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-U-R-G-E.
# Spelling mean and std: 0.240 +/- 0.304
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: brawn -> B-R-A-N-H.
# Spelling mean and std: 0.366 +/- 0.246
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.778 +/- 0.222
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> R-I-G-H.
# Spelling mean and std: 0.377 +/- 0.416
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.607 +/- 0.208
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-T-I-N.
# Spelling mean and std: 0.517 +/- 0.279
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lunar -> L-U-R-A.
# Spelling mean and std: 0.278 +/- 0.340
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-U-E.
# Spelling mean and std: 0.224 +/- 0.294
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-D-S-H-T.
# Spelling mean and std: 0.486 +/- 0.333
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-C-A-B.
# Spelling mean and std: 0.216 +/- 0.311
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-R-L.
# Spelling mean and std: 0.289 +/- 0.343
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-H-T.
# Spelling mean and std: 0.429 +/- 0.241
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-L-U-S.
# Spelling mean and std: 0.549 +/- 0.361
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-Z-E.
# Spelling mean and std: 0.464 +/- 0.348
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-U-I-M-P-H.
# Spelling mean and std: 0.674 +/- 0.111
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-S-I-R.
# Spelling mean and std: 0.318 +/- 0.321
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-I-C-O.
# Spelling mean and std: 0.385 +/- 0.214
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-A-U-P-E.
# Spelling mean and std: -0.016 +/- 0.155
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.102 +/- 1.056
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: wisp -> W-I-P-S.
# Spelling mean and std: 0.571 +/- 0.286
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-A-T-R-U-T-E.
# Spelling mean and std: 0.208 +/- 0.159
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-T.
# Spelling mean and std: 0.298 +/- 0.301
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-P-A-I-R-H.
# Spelling mean and std: 0.513 +/- 0.317
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-E-O-T.
# Spelling mean and std: 0.030 +/- 0.235
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-I-R-U-M-P-H-I-R.
# Spelling mean and std: 0.346 +/- 0.200
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I.
# Spelling mean and std: 0.625 +/- 0.179
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-C-U-R-L-I-S.
# Spelling mean and std: 0.317 +/- 0.321
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-E-T-O.
# Spelling mean and std: 0.344 +/- 0.419
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: enchant -> E-N-C-A-P-T.
# Spelling mean and std: 0.277 +/- 0.172
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-A-B.
# Spelling mean and std: 0.539 +/- 0.264
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-R-G-E.
# Spelling mean and std: 0.326 +/- 0.223
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-O-S-H-O-P-I-S-Y.
# Spelling mean and std: 0.580 +/- 0.274
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-H-E-L.
# Spelling mean and std: 0.274 +/- 0.172
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-R-P-E-R-T-O-R.
# Spelling mean and std: -0.195 +/- 0.318
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-S-E-A.
# Spelling mean and std: 0.396 +/- 0.364
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-L-O.
# Spelling mean and std: 0.285 +/- 0.297
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-B-U.
# Spelling mean and std: 0.288 +/- 0.220
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-A-N-N-B-L.
# Spelling mean and std: 0.318 +/- 0.331
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-I-K-N.
# Spelling mean and std: 0.057 +/- 0.156
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-O-R-H-A-T.
# Spelling mean and std: 0.352 +/- 0.171
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> H-W-I-S-E.
# Spelling mean and std: 0.288 +/- 0.235
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-Q-I-R-E.
# Spelling mean and std: 0.064 +/- 0.408
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: echo -> E-H-C-E-R.
# Spelling mean and std: 0.048 +/- 0.270
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-I-S-P-S.
# Spelling mean and std: 0.438 +/- 0.317
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-R-H-D.
# Spelling mean and std: 0.592 +/- 0.379
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-N-Y.
# Spelling mean and std: 0.364 +/- 0.248
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-P-L-E.
# Spelling mean and std: 0.578 +/- 0.260
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-O-S.
# Spelling mean and std: 0.187 +/- 0.323
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-C-T.
# Spelling mean and std: 0.216 +/- 0.163
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-I-P-F-E.
# Spelling mean and std: 0.297 +/- 0.255
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-A-P-R.
# Spelling mean and std: 0.163 +/- 0.212
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-Y-T.
# Spelling mean and std: 0.087 +/- 0.540
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-O-T-E.
# Spelling mean and std: 0.383 +/- 0.262
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-H-R-E.
# Spelling mean and std: 0.188 +/- 0.185
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I.
# Spelling mean and std: 0.377 +/- 0.167
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-U-H-M-T.
# Spelling mean and std: -0.045 +/- 0.045
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-N-T-L-R.
# Spelling mean and std: 0.455 +/- 0.399
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> ZA-E-L-O-U-S.
# Spelling mean and std: 0.214 +/- 0.499
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: elude -> E-L-U-D-E.
# Spelling mean and std: 0.147 +/- 0.407
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-A-T-R-E.
# Spelling mean and std: 0.043 +/- 0.317
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.531 +/- 0.375
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-I-T.
# Spelling mean and std: 0.084 +/- 0.243
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-A-R-E-D.
# Spelling mean and std: 0.147 +/- 0.127
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.750 +/- 0.247
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-I-C-R-H.
# Spelling mean and std: 0.283 +/- 0.202
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-C-A-R-D.
# Spelling mean and std: 0.452 +/- 0.281
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-U-R-E-V.
# Spelling mean and std: 0.415 +/- 0.350
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-R-T.
# Spelling mean and std: 0.226 +/- 0.148
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-T.
# Spelling mean and std: 0.328 +/- 0.176
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.786 +/- 0.189
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-I-S-E-L.
# Spelling mean and std: 0.131 +/- 0.322
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.426 +/- 0.155
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-I-N.
# Spelling mean and std: 0.561 +/- 0.303
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-L-E-V-T.
# Spelling mean and std: 0.173 +/- 0.298
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-Z-E.
# Spelling mean and std: 0.710 +/- 0.303
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-I-T.
# Spelling mean and std: 0.087 +/- 0.366
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# TrainOutput(global_step=270, training_loss=0.005609922766409538, metrics={'train_runtime': 261.4592, 'train_samples_per_second': 2.104, 'train_steps_per_second': 1.033, 'total_flos': 0.0, 'train_loss': 0.005609922766409538})

# %% [markdown]
# Now we define the `SFTTrainer` and run the fine-tuning process.

# %% [markdown]
# ## Step 5. Evaluate the fine-tuned model

# %%
# Evaluate the fine-tuned model on the same training examples
# No changes needed in this cell

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    completion = example["completion"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=completion,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# /voc/data/venv2/lib/python3.12/site-packages/torch/utils/checkpoint.py:86: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# Proposed: T-R-I-U-M-P-H. | Actual: T-R-I-U-M-P-H. | Matches: ✅
# Proposed: S-A-P-L-I-C-H. | Actual: S-A-P-P-H-I-R-E. | Matches: ❌
# Proposed: E-X-P-S-T. | Actual: E-X-P-O-S-E. | Matches: ❌
# Proposed: F-R-S-E-C-O-S. | Actual: F-R-E-S-C-O-S. | Matches: ❌
# Proposed: W-I-P-S. | Actual: W-I-S-P. | Matches: ❌
# Proposed: M-I-R-A-G. | Actual: M-I-R-A-G-E. | Matches: ❌
# Proposed: I-V-O-R-Y. | Actual: I-V-O-R-Y. | Matches: ✅
# Proposed: O-N-S-H-O-R-D. | Actual: O-N-S-E-T. | Matches: ❌
# Proposed: E-L-U-D-E. | Actual: E-L-U-D-E. | Matches: ✅
# Proposed: S-P-H-I-N-X. | Actual: S-P-H-I-N-X. | Matches: ✅
# Proposed: B-R-A-N-E. | Actual: B-R-A-W-N. | Matches: ❌
# Proposed: G-O-S-H-O-P-I. | Actual: G-O-S-S-I-P-Y. | Matches: ❌
# Proposed: E-N-C-H-A-N. | Actual: E-N-C-H-A-N-T. | Matches: ❌
# Proposed: T-A-A-N-R. | Actual: T-A-V-E-R-N. | Matches: ❌
# Proposed: W-H-I-S-T. | Actual: W-H-I-S-T-L-E. | Matches: ❌
# Proposed: C-U-P-H-R-E. | Actual: C-A-P-T-U-R-E. | Matches: ❌
# Proposed: E-C-H-O-R-E. | Actual: E-C-H-O. | Matches: ❌
# Proposed: M-I-R-T. | Actual: M-I-R-T-H. | Matches: ❌
# Proposed: C-R-I-S-P. | Actual: C-R-I-S-P. | Matches: ✅
# Proposed: Z-E-A-L-O-U-S. | Actual: Z-E-A-L-O-U-S. | Matches: ✅
# 14.13809523809524/20.0 words correct

# %% [markdown]
# The model now performs better on the training data it has seen. But has it generalized? Let's check its performance on the unseen test set.

# %%
# Evaluate the fine-tuned model on the unseen test set
# No changes needed in this cell

proportion_correct = 0.0
num_examples = len(ds["test"])

for example in ds["test"]:
    prompt = example["prompt"]
    completion = example["completion"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=completion,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/{num_examples}.0 words correct")
# Out:
# Proposed: W-R-Y-I-L-Y. | Actual: W-R-Y-L-Y. | Matches: ❌
# Proposed: G-I-L-N-I-S. | Actual: G-L-I-S-T-E-N. | Matches: ❌
# Proposed: S-C-A-Q-E. | Actual: Q-U-E-S-T. | Matches: ❌
# Proposed: C-R-E-E-A. | Actual: C-R-A-V-E. | Matches: ❌
# Proposed: L-U-S-I-R-O. | Actual: L-U-S-H. | Matches: ❌
# Proposed: F-A-L-I-T. | Actual: F-A-B-L-E. | Matches: ❌
# Proposed: K-N-A-R-K. | Actual: K-N-A-C-K. | Matches: ❌
# 3.225/7.0 words correct

# %% [markdown]
# It looks like it has improved! Perhaps with a larger dataset and more training, it could get even better.

# %% [markdown]
# ## Congratulations for completing the exercise! 🎉
#
# ✅ You did it! You successfully fine-tuned a small language model using PEFT with LoRA to teach it a new skill: spelling! You saw how the base model failed completely at the task, and with a very small amount of data and a short training run, the model started to learn how to spell.

# %% [markdown]
# <br /><br /><br /><br /><br /><br /><br /><br /><br />
